# %%
data='''char action = argv[2][0];
char *all_tests()
char *another = "Zed";
char arg[])
char arg[]);
char *arg = NULL;
char **argv[]) 
char *argv[])
char *as_string;
char * b;
char *) b;
char *) b0->data, (char *) b->data, i);
char) b0->data[i]) - ((char) b1->data[i]);
char *) (b0->data + pos), (char *) aux->data, aux->slen);
char *) &b->data[b->slen];
char) ((b->data[i] == '\0') ? z : (char) (b->data[i]));
char *) (b->data + pos),
char *) (b->data + pos + len), 
char *) blk)[i]) {
char *) blk)[i])) return 0;
char *) blk)[i]) return BSTR_OK;
char *) blk || len == 0) return 1;
char *block = NULL;
char * bstr2cstr (const_bstring b, char z) {
char * bstr2cstr (const_bstring s, char z)
char *) bstr__alloc (b->mlen = i))) {
char *) bstr__alloc (c);
char *) bstr__alloc (j);
char *) bstr__alloc ((size_t) b->mlen);
char *) bstr__alloc ((size_t) (l + 1));
char *) bstr__alloc ((size_t) len))) {
char (bstring b, char c)
char (bstring b, char c) {
char *) bstr__memchr ((b->data + pos), (unsigned char) c, (b->slen - pos));
char *) bstr__realloc (b->data, (size_t) len);
char *) bstr__realloc (b->data, (size_t) (len = olen)))) {
char *) buff->data);
char * buffer which is equal to the contents of 
char c;
char) (c)])
char) c))
char) c;
char c0;
char c1;
char ch)
char ch);
char ch = '\0';
char ch = arg[i];
char *config_opts = NULL;
char *configure_opts, const char *make_opts,
char) c) return i;
char c = (unsigned char) data[i];
char c = (unsigned char) downcase (b0->data[i]);
char **cur_name = names;
char * d;
char * d0;
char * d0, * d1;
char * d1;
char *data);
char *data = argv[3];
char *data, int count, char expects)
char * data, int len, int pos, const struct charField * cf) {
char * data, int pos, const struct charField * cf) {
char *data = (unsigned char *)cmp;
char *depends_file = NULL;
char *description;
char) downcase (b0->data[i])
char) downcase (b0->data[i]);
char) downcase (b0->data[m]);
char) downcase (b0->data[n]);
char) downcase (b1->data[i]);
char) downcase (b1->data[i])) return 0;
char) downcase (b1->data[m]);
char) downcase (b1->data[n]);
char) downcase (b->data[i]);
char) downcase (s[i])))
char *email)
char email[MAX_DATA];
char(encname, ' ');
char *EYE_COLOR_NAMES[] = {
char = fgetc(stdin);
charField */
charField));
charField * cf) {
charField cf;
charField * cf, const_bstring b) {
charField chrs;
charField { LONG_TYPE content[CFCLEN]; };
charField { unsigned char content[CFCLEN]; };
char *file)
char *file_name)
char *filename = argv[1];
char *filename, char mode)
char *filename, int search_len, char *search_for[])
char *filename, int use_or, int search_len, char *search_for[])
char fill)
char fill) {
char first_name[MAX_DATA];
char *first_name = NULL;
char first_name[] = "Zed";
char * fmt, ...)
char * fmt, ...) {
char *fmt, ...)
char * fmt, va_list arg) {
char * fmt, va_list arglist)
char *found = NULL;
char from[1003] = { 'a' };
char *from, char *to, int count)
char *from, int to_len, char *to)
char full_name[] = {
char *func_to_run = argv[2];
char *func_to_run, const char *data,
char *host = argv[1];
char *host, char *port)
char *host, const char *port)
char *host, const char *port, const char *store_path)
char initial = ' ';
char initial = 'A';
char *in = NULL;
char *input = NULL;
char **inputs = argv + 1;
char *install_opts)
char *install_opts = NULL;
char *key = NULL;
char last_name[MAX_DATA];
char *last_name = NULL;
char last_name[] = "Shaw";
char letter = argv[1][i];
char *lib_file = argv[1];
char *lib_file = "build/libYOUR_LIBRARY.so";
char *line;
char *line = calloc(MAX_LINE, 1);
char line_ending)
char LINE_ENDING = '\n';
char(line, '\n');
char *make_opts = NULL;
char *message)
char *msg)
char *name,
char *name;
char name[4] = { 'a', 'a', 'a', 'a' };
char *name, int age, int height,
char name[MAX_DATA];
char *names[] = {
char name[] = "Zed";
char nul_byte = '\0';
char *optarg = NULL;
char *out_char = NULL;
char **out_string, int max_buffer)
char **out_string = NULL;
char * p;
char *path)
char *path, const char *mode)
char *path = realpath(store_path, NULL);
char *port = argv[2];
char *prompt)
char * r;
char *) (r->data + r->slen);
char *res = strncpy(addr->name, name, MAX_DATA);
char *result = fgets(*out_string, max_buffer, stdin);
char * s)
char * s) {
char * s;
char *s)
char *) s->buff->data;
char) s[i] && 
char) s[i]) return BSTR_OK;
char splitChar)
char splitChar) {
char splitChar, int pos,
char *states[] = {
char *store_path)
char *store_path = argv[3];
char * str)
char * str) {
char * string s.  The C string s must be '\0' 
char * string str.  Note that 
char * string to a bstring.
char *temp = malloc(100);
char terminator)
char terminator) {
char *test_create()
char *test_dlclose()
char *test_dlopen()
char *test_dlopen(int stuff)
char *test_dummy()
char *test_encrypt_armor_name()
char *test_failures()
char *test_functions()
char *test = NULL;
char *test_path_parsing()
char *test_path_sanitize_armor()
char *test_sample()
char *test_store_load()
char to[1003] = { 'c' };
char to[], char from[])
char) upcase (b->data[i]);
char *url)
char *url,
char *url, int fetch_only)
char *url = NULL;
char = va_arg(argp, char *);
char * x;
'''

# %%
import re

# %%
keep =[]
for line in data.splitlines():
    if 'char)' not in line:
        if 'char *)' not in line:
            if not re.findall('charField',line):
                    for ix in [x.strip() for x in line.split('char ') if x]:
                        keep.append(ix)

# %%
keep
# Out:
# ['action = argv[2][0];',
#  '*all_tests()',
#  '*another = "Zed";',
#  'arg[])',
#  'arg[]);',
#  '*arg = NULL;',
#  '**argv[])',
#  '*argv[])',
#  '*as_string;',
#  '* b;',
#  '*block = NULL;',
#  '* bstr2cstr (const_bstring b,',
#  'z) {',
#  '* bstr2cstr (const_bstring s,',
#  'z)',
#  '(bstring b,',
#  'c)',
#  '(bstring b,',
#  'c) {',
#  '* buffer which is equal to the contents of',
#  'c;',
#  'c0;',
#  'c1;',
#  'ch)',
#  'ch);',
#  "ch = '\x00';",
#  'ch = arg[i];',
#  '*config_opts = NULL;',
#  '*configure_opts, const',
#  '*make_opts,',
#  '**cur_name = names;',
#  '* d;',
#  '* d0;',
#  '* d0, * d1;',
#  '* d1;',
#  '*data);',
#  '*data = argv[3];',
#  '*data, int count,',
#  'expects)',
#  '*depends_file = NULL;',
#  '*description;',
#  '*email)',
#  'email[MAX_DATA];',
#  "char(encname, ' ');",
#  '*EYE_COLOR_NAMES[] = {',
#  '= fgetc(stdin);',
#  '*file)',
#  '*file_name)',
#  '*filename = argv[1];',
#  '*filename,',
#  'mode)',
#  '*filename, int search_len,',
# ...

# %%
f = open('/tmp/wanted')
data = f.readlines()
data = [x.replace('\n','') for x in data]
f.close()

# %%
from trie import Trie
trie = Trie(keep)

# %%
trie.keys()
# Out:
# dict_keys(['a', '*', 'z', '(', 'c', 'e', '=', 'm', 'f', 'i', 'l', 'L', "'", 'n', 's', 't'])

# %%
char {WS}+"*"?{WS*}{lower}{alphnum}+;
# Out:
# ['char action = argv[2][0];',
#  'char *all_tests()',
#  'char *another = "Zed";',
#  'char arg[])',
#  'char arg[]);',
#  'char *arg = NULL;',
#  'char **argv[]) ',
#  'char *argv[])',
#  'char *as_string;',
#  'char * b;',
#  'char *block = NULL;',
#  'char * bstr2cstr (const_bstring b, char z) {',
#  'char * bstr2cstr (const_bstring s, char z)',
#  'char (bstring b, char c)',
#  'char (bstring b, char c) {',
#  'char * buffer which is equal to the contents of ',
#  'char c;',
#  'char c0;',
#  'char c1;',
#  'char ch)',
#  'char ch);',
#  "char ch = '\x00';",
#  'char ch = arg[i];',
#  'char *config_opts = NULL;',
#  'char *configure_opts, const char *make_opts,',
#  'char **cur_name = names;',
#  'char * d;',
#  'char * d0;',
#  'char * d0, * d1;',
#  'char * d1;',
#  'char *data);',
#  'char *data = argv[3];',
#  'char *data, int count, char expects)',
#  'char *depends_file = NULL;',
#  'char *description;',
#  'char *email)',
#  'char email[MAX_DATA];',
# ...

# %%
trie['#']['X'][' '].keys()
# Out:
# dict_keys(['<', '"'])

# %%
import re
from collections import defaultdict
dct=defaultdict(set)
def read_file(path,f_name):
    with open('{}/{}'.format(path,f_name),'r',encoding='ISO-8859-1') as f:
        data = f.read()
    return data

# %%
lst = re.findall('((?:^|\n)[a-zA-Z]+.*?:.*?);',read_file('/home/user','c.g4'),re.DOTALL)

# %%
resp = [[y.strip() for y in re.split(r'\\t|\||\'',x) if y] for x in lst[1].split('\n')[2:]]

# %%
id_word=re.findall('(.*?):',lst[1])
id_word = id_word[0]

# %%
for l in resp:
    if len(l) ==2:
        print(l[1])
        dct[id_word].add(l[1])
# Out:
# auto
# break
# case
# const
# continue
# default
# goto
# enum
# for
# return
# signed
# sizeof
# auto
# break
# case
# char
# const
# continue
# default
# double
# else
# enum
# extern
# float
# goto
# if
# int
# long
# return
# short
# signed
# sizeof
# struct
# switch
# typedef
# unsigned
# void

# %%
dct
# Out:
# defaultdict(set,
#             {'keyword': {'auto',
#               'break',
#               'case',
#               'char',
#               'const',
#               'continue',
#               'default',
#               'double',
#               'else',
#               'enum',
#               'extern',
#               'float',
#               'for',
#               'goto',
#               'if',
#               'int',
#               'long',
#               'return',
#               'short',
#               'signed',
#               'sizeof',
#               'struct',
#               'switch',
#               'typedef',
#               'unsigned',
#               'void'}})

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
from nltk.tokenize import mwe
stopwords = set(nltk.corpus.stopwords.words('english'))
tokenizer = mwe.MWETokenizer(separator='')
TOKEN_MIN_LENGTH = 3
seen = []
def add_new_token(string):
    tokenizer.add_mwe(r'{}'.format(string))
    seen.append(r'{}'.format(string))

# %%
path ='/home/user/c/examples'
from os import listdir
files = listdir(path)

# %%
c_prog = read_file(path,files[0])

# %%
add_new_token('char')

# %%
words = [x for x in set(re.findall('[a-z]+',data)) if len(x) >2]

# %%
for word in words:
        add_new_token(word)

# %%
word_replace={' ':'SPACE','=':'EQ',"[":'LBRACE',']':'RBRACE','*':'STAR','(':'LPAREN',')':'RPAREN'}

# %%
def replace_word(x):
    import re
    if str(x).isdigit():
        return 'INT'
    if x in word_replace.keys():
        return word_replace.get(x)
    else:
        return x
trie_test = []
for line in data.splitlines():
    trie_test.append([replace_word(x) for x in tokenizer.tokenize(line)])

# %%
trie = Trie(trie_test)

# %%
trie.keys()
# Out:
# dict_keys(['char', "'"])

# %%
trie['char']['SPACE'].keys()
# Out:
# dict_keys(['action', 'STAR', 'arg', 'LPAREN', 'c', 'email', 'EQ', 'fill', 'first', 'from', 'full', 'initial', 'last', 'letter', 'line', 'L', 'name', 'nul', 'split', 'terminator', 't'])

# %%
data.splitlines()
# Out:
# ['char action = argv[2][0];',
#  'char *all_tests()',
#  'char *another = "Zed";',
#  'char arg[])',
#  'char arg[]);',
#  'char *arg = NULL;',
#  'char **argv[]) ',
#  'char *argv[])',
#  'char *as_string;',
#  'char * b;',
#  'char *) b;',
#  'char *) b0->data, (char *) b->data, i);',
#  'char) b0->data[i]) - ((char) b1->data[i]);',
#  'char *) (b0->data + pos), (char *) aux->data, aux->slen);',
#  'char *) &b->data[b->slen];',
#  "char) ((b->data[i] == '\x00') ? z : (char) (b->data[i]));",
#  'char *) (b->data + pos),',
#  'char *) (b->data + pos + len), ',
#  'char *) blk)[i]) {',
#  'char *) blk)[i])) return 0;',
#  'char *) blk)[i]) return BSTR_OK;',
#  'char *) blk || len == 0) return 1;',
#  'char *block = NULL;',
#  'char * bstr2cstr (const_bstring b, char z) {',
#  'char * bstr2cstr (const_bstring s, char z)',
#  'char *) bstr__alloc (b->mlen = i))) {',
#  'char *) bstr__alloc (c);',
#  'char *) bstr__alloc (j);',
#  'char *) bstr__alloc ((size_t) b->mlen);',
# ...
